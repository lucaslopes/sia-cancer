# %%
import pandas as pd

# %%
df_path = '~/Databases/sia/SIA.parquet'
df = pd.read_parquet(df_path)
df
# Out:
#         AP_CODUNI  AP_CMP   AP_PRIPAL              AP_VL_AP AP_UFMUN AP_TPUPS  \
# 0         2001586  201801  0304020079                751.00   120040       05
# 1         2001586  201801  0304030031                150.00   120040       05
# 2         2001586  201801  0304020060                147.10   120040       05
# 3         2001586  201801  0304020079                301.50   120040       05
# 4         2001586  201801  0304020079                751.00   120040       05
# ...           ...     ...         ...                   ...      ...      ...
# 1861547   9255400  201912  0304010456               5838.00   172100       36
# 1861548   9255400  201911  0304010456               5838.00   172100       36
# 1861549   9255400  201912  0304010456               5838.00   172100       36
# 1861550   9255400  201912  0304010456               5838.00   172100       36
# 1861551   9255400  201912  0304010456               5838.00   172100       36
#
# ...

# %%
cols = ['APAC', 'ANO']
df[cols]
df['count'] = 1
df_sum = df[cols+['count']].groupby(cols, as_index=False).sum()
print(df_sum)
df_sum
# Out:
#   APAC   ANO   count
# 0   AQ  2018  841406
# 1   AQ  2019  886039
# 2   AR  2018   81530
# 3   AR  2019   52577
#   APAC   ANO   count
# 0   AQ  2018  841406
# 1   AQ  2019  886039
# 2   AR  2018   81530
# 3   AR  2019   52577
